# %% [markdown]
# ### Human in the Loop

# %%
import os
from langchain.chat_models import init_chat_model
llm = init_chat_model("groq:openai/gpt-oss-120b")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x1337ce3d0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x133dde1c0>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
from typing import Annotated

from langchain_tavily import TavilySearch
from langchain_core.tools import tool
from typing_extensions import TypedDict

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition

from langgraph.types import Command, interrupt

class State(TypedDict):
    messages: Annotated[list, add_messages]

graph_builder = StateGraph(State)

@tool
def human_assistance(query: str) -> str:
    """Request assistance from a human."""
    human_response = interrupt({"query": query})
    return human_response["data"]

tool = TavilySearch(max_results=2)
tools = [tool, human_assistance]
llm_with_tools = llm.bind_tools(tools)

def chatbot(state: State):
    message = llm_with_tools.invoke(state["messages"])
    # Because we will be interrupting during tool execution,
    # we disable parallel tool calling to avoid repeating any
    # tool invocations when we resume.
    
    return {"messages": [message]}

graph_builder.add_node("chatbot", chatbot)

tool_node = ToolNode(tools=tools)
graph_builder.add_node("tools", tool_node)

graph_builder.add_conditional_edges(
    "chatbot",
    tools_condition,
)
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

# %%
memory = MemorySaver()

graph = graph_builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
user_input = "I need some expert guidance and assistance for building an AI agent. Could you request assistance for me?"
config = {"configurable": {"thread_id": "1"}}

events = graph.stream(
    {"messages": user_input},
    config,
    stream_mode="values",
)
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# I need some expert guidance and assistance for building an AI agent. Could you request assistance for me?
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (fc_8056a504-3527-474d-aa90-a8a7aa7156bd)
#  Call ID: fc_8056a504-3527-474d-aa90-a8a7aa7156bd
#   Args:
#     query: User needs expert guidance and assistance for building an AI agent. Please provide detailed help.

# %%
human_response = (
    "We, the experts are here to help! We'd recommend you check out LangGraph to build your agent."
    " It's much more reliable and extensible than simple autonomous agents."
)

human_command = Command(resume={"data": human_response})

events = graph.stream(human_command, config, stream_mode="values")
for event in events:
    if "messages" in event:
        event["messages"][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   human_assistance (fc_8056a504-3527-474d-aa90-a8a7aa7156bd)
#  Call ID: fc_8056a504-3527-474d-aa90-a8a7aa7156bd
#   Args:
#     query: User needs expert guidance and assistance for building an AI agent. Please provide detailed help.
# ================================= Tool Message =================================
# Name: human_assistance
#
# We, the experts are here to help! We'd recommend you check out LangGraph to build your agent. It's much more reliable and extensible than simple autonomous agents.
# ================================== Ai Message ==================================
#
# Absolutely—here’s what the experts suggest:
#
# ### 📚 Recommended Framework: **LangGraph**
# LangGraph is a powerful, extensible library for building **composable, state‑driven AI agents**. It lets you:
#
# - **Chain together multiple LLM calls** (or other tools) with clear state management.
# - **Define reusable “nodes”** (functions, prompts, tool calls) that can be wired into complex workflows.
# - **Handle loops, conditionals, and branching** without writing brittle “prompt‑only” logic.
# - **Persist and visualize execution graphs**, making debugging and iteration far easier.
#
# ---
#
# ## 🚀 Getting Started with LangGraph
#
# | Step | What to Do | Key Resources |
# |------|------------|----------------|
# | **1. Install** | ```bash pip install langgraph``` | [PyPI page](https://pypi.org/project/langgraph/) |
# | **2. Set up LLM provider** | Choose OpenAI, Anthropic, Groq, etc., and configure your API key. | <https://langgraph.dev/docs/getting-started#llm-setup> |
# | **3. Define Nodes** | Write Python functions (or async coroutines) that represent each step: e.g., `retrieve_context`, `generate_answer`, `call_tool`. | <https://langgraph.dev/docs/nodes> |
# | **4. Build the Graph** | Use `StateGraph` to wire nodes together, specifying edges (transitions) and conditional logic. | <https://langgraph.dev/docs/graph> |
# | **5. Run & Debug** | Call `graph.invoke(initial_state)` and inspect the returned state or visual graph. | <https://langgraph.dev/docs/debugging> |
# | **6. Persist & Deploy** | Serialize the graph, host it on a serverless function, or embed in a larger app. | <https://langgraph.dev/docs/deployment> |
#
# ---
#
# ## 🎯 Example: A Simple Q&A Agent
#
# ```python
# from langgraph.graph import StateGraph, START, END
# from langgraph.checkpoint import MemoryCheckpoint
# from langchain_openai import ChatOpenAI
#
# # 1️⃣ LLM client
# llm = ChatOpenAI(model="gpt-4o-mini")
#
# # 2️⃣ Define nodes
# def retrieve_context(state):
#     query = state["question"]
#     # (Insert your retrieval logic – e.g., vector DB search)
#     context = f"Relevant docs for: {query}"
#     return {"context": context}
#
# def generate_answer(state):
#     prompt = f"""You are a helpful assistant. Use the following context to answer the question.
#
# Context:
# {state["context"]}
#
# Question:
# {state["question"]}"""
#     response = llm.invoke(prompt).content
#     return {"answer": response}
#
# # 3️⃣ Build the graph
# graph = StateGraph()
# graph.add_node("retrieve", retrieve_context)
# graph.add_node("answer", generate_answer)
#
# graph.add_edge(START, "retrieve")
# graph.add_edge("retrieve", "answer")
# graph.add_edge("answer", END)
#
# # 4️⃣ Create a checkpoint (optional, for persistence)
# checkpoint = MemoryCheckpoint()
# graph = graph.compile(checkpointer=checkpoint)
#
# # 5️⃣ Run the agent
# result = graph.invoke({"question": "What are the health benefits of meditation?"})
# print(result["answer"])
# ```
#
# **What’s happening?**
#
# 1. **`retrieve_context`** pulls relevant information (you can plug in any vector store or API).
# 2. **`generate_answer`** feeds that context plus the original question to the LLM.
# 3. The **state** (`dict`) flows from node to node, making it easy to add more steps later (e.g., tool calls, validation, feedback loops).
#
# ---
#
# ## 🛠️ Extending the Agent
#
# | Feature | How to Add in LangGraph |
# |---------|--------------------------|
# | **Tool Calls** (e.g., calculator, web search) | Create a node that calls the external API and returns its output into the state. |
# | **Looping / Re‑asking** | Use `graph.add_conditional_edge` to loop back to a previous node based on a flag (e.g., `needs_more_info`). |
# | **User Feedback** | Add a node that presents the answer and captures a thumbs‑up/down, then routes accordingly. |
# | **Multi‑modal (image, audio)** | Include nodes that invoke vision or speech models; just pass the raw bytes in the state. |
# | **Parallel Branches** | Use `graph.add_edge` from a node to multiple successors; each branch runs concurrently (use async nodes). |
#
# ---
#
# ## 📖 Further Reading & Community
#
# - **LangGraph Docs:** <https://langgraph.dev> (full tutorials, API reference, and examples)
# - **GitHub Repo:** <https://github.com/langchain-ai/langgraph> (star it, explore the `examples/` folder)
# - **Discord / Forum:** Join the LangChain community for live help: <https://discord.gg/langchain>
# - **Blog Post:** “Building Robust LLM Agents with LangGraph” – a step‑by‑step walkthrough (search the LangChain blog).
#
# ---
#
# ## 🙋‍♀️ What Next?
#
# 1. **Try the quick‑start notebook** from the docs to see a live graph in action.
# 2. **Identify the pieces** your specific agent needs (retrieval, tool use, memory, etc.).
# 3. **Sketch a flow diagram** (even a pen‑and‑paper sketch) of the states and transitions—LangGraph mirrors that diagram directly.
# 4. **Iterate**: add one node at a time, test, and watch the graph visualizer update.
#
# If you hit any roadblocks—whether it’s wiring a particular tool, handling async calls, or designing a feedback loop—just let me know the exact point of friction, and I can dive deeper with code snippets or troubleshooting tips. Happy building! 🚀

# %% [markdown]
# ![Screenshot 2026-05-07 at 6.09.14 AM.png](<attachment:Screenshot 2026-05-07 at 6.09.14 AM.png>)
